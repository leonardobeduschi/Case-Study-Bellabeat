# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
daily_activity = pd.read_csv("/content/bellabeat/dailyActivity_merged.csv")
heart_rate = pd.read_csv("/content/bellabeat/heartrate_seconds_merged.csv")
hourly_calories = pd.read_csv("/content/bellabeat/hourlyCalories_merged.csv")
hourly_intensities = pd.read_csv("/content/bellabeat/hourlyIntensities_merged.csv")
hourly_steps = pd.read_csv("/content/bellabeat/hourlySteps_merged.csv")
minute_calories = pd.read_csv("/content/bellabeat/minuteCaloriesNarrow_merged.csv")
minute_intensities = pd.read_csv("/content/bellabeat/minuteIntensitiesNarrow_merged.csv")
minute_METs = pd.read_csv("/content/bellabeat/minuteMETsNarrow_merged.csv")
minute_sleep = pd.read_csv("/content/bellabeat/minuteSleep_merged.csv")
minute_steps = pd.read_csv("/content/bellabeat/minuteStepsNarrow_merged.csv")
weight = pd.read_csv("/content/bellabeat/weightLogInfo_merged.csv")

# %%
datasets = [
    ("daily_activity", daily_activity),
    ("heart_rate", heart_rate),
    ("hourly_calories", hourly_calories),
    ("hourly_intensities", hourly_intensities),
    ("hourly_steps", hourly_steps),
    ("minute_calories", minute_calories),
    ("minute_intensities", minute_intensities),
    ("minute_METs", minute_METs),
    ("minute_sleep", minute_sleep),
    ("minute_steps", minute_steps),
    ("weight", weight)
]

# %% [markdown]
# # Analyzing each dataset

# %% [markdown]
# Using the function head() to analyze the first 5 rows of the dataset

# %%
daily_activity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
heart_rate.head()
# Out:
#            Id                 Time  Value
# 0  2022484408  4/1/2016 7:54:00 AM     93
# 1  2022484408  4/1/2016 7:54:05 AM     91
# 2  2022484408  4/1/2016 7:54:10 AM     96
# 3  2022484408  4/1/2016 7:54:15 AM     98
# 4  2022484408  4/1/2016 7:54:20 AM    100

# %%
hourly_calories.head()
# Out:
#            Id           ActivityHour  Calories
# 0  1503960366  3/12/2016 12:00:00 AM        48
# 1  1503960366   3/12/2016 1:00:00 AM        48
# 2  1503960366   3/12/2016 2:00:00 AM        48
# 3  1503960366   3/12/2016 3:00:00 AM        48
# 4  1503960366   3/12/2016 4:00:00 AM        48

# %%
hourly_intensities.head()
# Out:
#            Id           ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366  3/12/2016 12:00:00 AM               0               0.0
# 1  1503960366   3/12/2016 1:00:00 AM               0               0.0
# 2  1503960366   3/12/2016 2:00:00 AM               0               0.0
# 3  1503960366   3/12/2016 3:00:00 AM               0               0.0
# 4  1503960366   3/12/2016 4:00:00 AM               0               0.0

# %%
hourly_steps.head()
# Out:
#            Id           ActivityHour  StepTotal
# 0  1503960366  3/12/2016 12:00:00 AM          0
# 1  1503960366   3/12/2016 1:00:00 AM          0
# 2  1503960366   3/12/2016 2:00:00 AM          0
# 3  1503960366   3/12/2016 3:00:00 AM          0
# 4  1503960366   3/12/2016 4:00:00 AM          0

# %%
minute_calories.head()
# Out:
#            Id         ActivityMinute  Calories
# 0  1503960366  3/12/2016 12:00:00 AM    0.7973
# 1  1503960366  3/12/2016 12:01:00 AM    0.7973
# 2  1503960366  3/12/2016 12:02:00 AM    0.7973
# 3  1503960366  3/12/2016 12:03:00 AM    0.7973
# 4  1503960366  3/12/2016 12:04:00 AM    0.7973

# %%
minute_intensities.head()
# Out:
#            Id         ActivityMinute  Intensity
# 0  1503960366  3/12/2016 12:00:00 AM          0
# 1  1503960366  3/12/2016 12:01:00 AM          0
# 2  1503960366  3/12/2016 12:02:00 AM          0
# 3  1503960366  3/12/2016 12:03:00 AM          0
# 4  1503960366  3/12/2016 12:04:00 AM          0

# %%
minute_METs.head()
# Out:
#            Id         ActivityMinute  METs
# 0  1503960366  3/12/2016 12:00:00 AM    10
# 1  1503960366  3/12/2016 12:01:00 AM    10
# 2  1503960366  3/12/2016 12:02:00 AM    10
# 3  1503960366  3/12/2016 12:03:00 AM    10
# 4  1503960366  3/12/2016 12:04:00 AM    10

# %%
minute_sleep.head()
# Out:
#            Id                  date  value        logId
# 0  1503960366  3/13/2016 2:39:30 AM      1  11114919637
# 1  1503960366  3/13/2016 2:40:30 AM      1  11114919637
# 2  1503960366  3/13/2016 2:41:30 AM      1  11114919637
# 3  1503960366  3/13/2016 2:42:30 AM      1  11114919637
# 4  1503960366  3/13/2016 2:43:30 AM      1  11114919637

# %%
minute_steps.head()
# Out:
#            Id         ActivityMinute  Steps
# 0  1503960366  3/12/2016 12:00:00 AM      0
# 1  1503960366  3/12/2016 12:01:00 AM      0
# 2  1503960366  3/12/2016 12:02:00 AM      0
# 3  1503960366  3/12/2016 12:03:00 AM      0
# 4  1503960366  3/12/2016 12:04:00 AM      0

# %%
weight.head()
# Out:
#            Id                  Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366  4/5/2016 11:59:59 PM   53.299999    117.506384  22.0
# 1  1927972279  4/10/2016 6:33:26 PM  129.600006    285.719105   NaN
# 2  2347167796  4/3/2016 11:59:59 PM   63.400002    139.773078  10.0
# 3  2873212765  4/6/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  4/7/2016 11:59:59 PM   57.200001    126.104416   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.969999            True  1459900799000
# 1  46.169998           False  1460313206000
# 2  24.770000            True  1459727999000
# 3  21.450001            True  1459987199000
# 4  21.650000            True  1460073599000

# %%
for name, df in datasets:
  print(df.shape)
  print(df.columns)
  print(df.dtypes, "\n")
# Out:
# (457, 15)
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object
#
# (1154681, 3)
# Index(['Id', 'Time', 'Value'], dtype='object')
# Id        int64
# Time     object
# Value     int64
# dtype: object
#
# (24084, 3)
# Index(['Id', 'ActivityHour', 'Calories'], dtype='object')
# Id               int64
# ActivityHour    object
# Calories         int64
# dtype: object
#
# (24084, 4)
# Index(['Id', 'ActivityHour', 'TotalIntensity', 'AverageIntensity'], dtype='object')
# Id                    int64
# ActivityHour         object
# TotalIntensity        int64
# AverageIntensity    float64
# dtype: object
#
# (24084, 3)
# Index(['Id', 'ActivityHour', 'StepTotal'], dtype='object')
# Id               int64
# ActivityHour    object
# StepTotal        int64
# dtype: object
#
# (1445040, 3)
# Index(['Id', 'ActivityMinute', 'Calories'], dtype='object')
# Id                  int64
# ActivityMinute     object
# Calories          float64
# dtype: object
#
# (1445040, 3)
# Index(['Id', 'ActivityMinute', 'Intensity'], dtype='object')
# Id                 int64
# ActivityMinute    object
# Intensity          int64
# dtype: object
#
# (1445040, 3)
# Index(['Id', 'ActivityMinute', 'METs'], dtype='object')
# Id                 int64
# ActivityMinute    object
# METs               int64
# dtype: object
#
# (198559, 4)
# Index(['Id', 'date', 'value', 'logId'], dtype='object')
# Id        int64
# date     object
# value     int64
# logId     int64
# dtype: object
#
# (1445040, 3)
# Index(['Id', 'ActivityMinute', 'Steps'], dtype='object')
# Id                 int64
# ActivityMinute    object
# Steps              int64
# dtype: object
#
# (33, 8)
# Index(['Id', 'Date', 'WeightKg', 'WeightPounds', 'Fat', 'BMI',
#        'IsManualReport', 'LogId'],
#       dtype='object')
# Id                  int64
# Date               object
# WeightKg          float64
# WeightPounds      float64
# Fat               float64
# BMI               float64
# IsManualReport       bool
# LogId               int64
# dtype: object

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# Limpar todos os datasets

# %%
for name, df in datasets:
  df[df.duplicated()] # this formula will only give data that contain duplicate values

# %%
for name, df in datasets:
  df.isnull().sum() # this will generate the total of null values in the dateset

# %%
for name, df in datasets:
  print(f"Cleaning dataset: {name}")

  # remove duplicates
  df.drop_duplicates(inplace=True)

  # remove rows with N/A values
  df.isnull().sum()
  df.dropna(inplace=True)

  print(f"{name} cleaned succesfully!\n")
# Out:
# Cleaning dataset: daily_activity
# daily_activity cleaned succesfully!
#
# Cleaning dataset: heart_rate
# heart_rate cleaned succesfully!
#
# Cleaning dataset: hourly_calories
# hourly_calories cleaned succesfully!
#
# Cleaning dataset: hourly_intensities
# hourly_intensities cleaned succesfully!
#
# Cleaning dataset: hourly_steps
# hourly_steps cleaned succesfully!
#
# Cleaning dataset: minute_calories
# minute_calories cleaned succesfully!
#
# Cleaning dataset: minute_intensities
# minute_intensities cleaned succesfully!
#
# Cleaning dataset: minute_METs
# minute_METs cleaned succesfully!
#
# Cleaning dataset: minute_sleep
# minute_sleep cleaned succesfully!
#
# Cleaning dataset: minute_steps
# minute_steps cleaned succesfully!
#
# Cleaning dataset: weight
# weight cleaned succesfully!

# %%
for name, df in datasets:
  print(f"Preview of cleaned dataset {name}")
  print(df.head())
# Out:
# Preview of cleaned dataset daily_activity
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
# Preview of cleaned dataset heart_rate
#            Id                 Time  Value
# 0  2022484408  4/1/2016 7:54:00 AM     93
# 1  2022484408  4/1/2016 7:54:05 AM     91
# 2  2022484408  4/1/2016 7:54:10 AM     96
# 3  2022484408  4/1/2016 7:54:15 AM     98
# 4  2022484408  4/1/2016 7:54:20 AM    100
# Preview of cleaned dataset hourly_calories
#            Id           ActivityHour  Calories
# 0  1503960366  3/12/2016 12:00:00 AM        48
# 1  1503960366   3/12/2016 1:00:00 AM        48
# 2  1503960366   3/12/2016 2:00:00 AM        48
# 3  1503960366   3/12/2016 3:00:00 AM        48
# 4  1503960366   3/12/2016 4:00:00 AM        48
# Preview of cleaned dataset hourly_intensities
#            Id           ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366  3/12/2016 12:00:00 AM               0               0.0
# 1  1503960366   3/12/2016 1:00:00 AM               0               0.0
# 2  1503960366   3/12/2016 2:00:00 AM               0               0.0
# 3  1503960366   3/12/2016 3:00:00 AM               0               0.0
# 4  1503960366   3/12/2016 4:00:00 AM               0               0.0
# Preview of cleaned dataset hourly_steps
#            Id           ActivityHour  StepTotal
# 0  1503960366  3/12/2016 12:00:00 AM          0
# 1  1503960366   3/12/2016 1:00:00 AM          0
# 2  1503960366   3/12/2016 2:00:00 AM          0
# 3  1503960366   3/12/2016 3:00:00 AM          0
# 4  1503960366   3/12/2016 4:00:00 AM          0
# Preview of cleaned dataset minute_calories
#            Id         ActivityMinute  Calories
# 0  1503960366  3/12/2016 12:00:00 AM    0.7973
# 1  1503960366  3/12/2016 12:01:00 AM    0.7973
# 2  1503960366  3/12/2016 12:02:00 AM    0.7973
# 3  1503960366  3/12/2016 12:03:00 AM    0.7973
# 4  1503960366  3/12/2016 12:04:00 AM    0.7973
# Preview of cleaned dataset minute_intensities
#            Id         ActivityMinute  Intensity
# 0  1503960366  3/12/2016 12:00:00 AM          0
# 1  1503960366  3/12/2016 12:01:00 AM          0
# 2  1503960366  3/12/2016 12:02:00 AM          0
# 3  1503960366  3/12/2016 12:03:00 AM          0
# 4  1503960366  3/12/2016 12:04:00 AM          0
# Preview of cleaned dataset minute_METs
#            Id         ActivityMinute  METs
# 0  1503960366  3/12/2016 12:00:00 AM    10
# 1  1503960366  3/12/2016 12:01:00 AM    10
# 2  1503960366  3/12/2016 12:02:00 AM    10
# 3  1503960366  3/12/2016 12:03:00 AM    10
# 4  1503960366  3/12/2016 12:04:00 AM    10
# Preview of cleaned dataset minute_sleep
#            Id                  date  value        logId
# 0  1503960366  3/13/2016 2:39:30 AM      1  11114919637
# 1  1503960366  3/13/2016 2:40:30 AM      1  11114919637
# 2  1503960366  3/13/2016 2:41:30 AM      1  11114919637
# 3  1503960366  3/13/2016 2:42:30 AM      1  11114919637
# 4  1503960366  3/13/2016 2:43:30 AM      1  11114919637
# Preview of cleaned dataset minute_steps
#            Id         ActivityMinute  Steps
# 0  1503960366  3/12/2016 12:00:00 AM      0
# 1  1503960366  3/12/2016 12:01:00 AM      0
# 2  1503960366  3/12/2016 12:02:00 AM      0
# 3  1503960366  3/12/2016 12:03:00 AM      0
# 4  1503960366  3/12/2016 12:04:00 AM      0
# Preview of cleaned dataset weight
#            Id                  Date   WeightKg  WeightPounds   Fat        BMI  \
# 0  1503960366  4/5/2016 11:59:59 PM  53.299999    117.506384  22.0  22.969999
# 2  2347167796  4/3/2016 11:59:59 PM  63.400002    139.773078  10.0  24.770000
#
#    IsManualReport          LogId
# 0            True  1459900799000
# 2            True  1459727999000

# %%
for name, df in datasets:
  print(df.shape)
  print(df.info())
# Out:
# (457, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
#  13  SedentaryMinutes          457 non-null    int64
#  14  Calories                  457 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 53.7+ KB
# None
# (1154681, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1154681 entries, 0 to 1154680
# Data columns (total 3 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   Id      1154681 non-null  int64
#  1   Time    1154681 non-null  object
#  2   Value   1154681 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.4+ MB
# None
# (24084, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24084 entries, 0 to 24083
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            24084 non-null  int64
#  1   ActivityHour  24084 non-null  object
#  2   Calories      24084 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 564.6+ KB
# None
# (24084, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24084 entries, 0 to 24083
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                24084 non-null  int64
#  1   ActivityHour      24084 non-null  object
#  2   TotalIntensity    24084 non-null  int64
#  3   AverageIntensity  24084 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 752.8+ KB
# None
# (24084, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24084 entries, 0 to 24083
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            24084 non-null  int64
#  1   ActivityHour  24084 non-null  object
#  2   StepTotal     24084 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 564.6+ KB
# None
# (1445040, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445040 entries, 0 to 1445039
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1445040 non-null  int64
#  1   ActivityMinute  1445040 non-null  object
#  2   Calories        1445040 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 33.1+ MB
# None
# (1445040, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445040 entries, 0 to 1445039
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1445040 non-null  int64
#  1   ActivityMinute  1445040 non-null  object
#  2   Intensity       1445040 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 33.1+ MB
# None
# (1445040, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445040 entries, 0 to 1445039
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1445040 non-null  int64
#  1   ActivityMinute  1445040 non-null  object
#  2   METs            1445040 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 33.1+ MB
# None
# (198034, 4)
# <class 'pandas.core.frame.DataFrame'>
# Index: 198034 entries, 0 to 198558
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Id      198034 non-null  int64
#  1   date    198034 non-null  object
#  2   value   198034 non-null  int64
#  3   logId   198034 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 7.6+ MB
# None
# (1445040, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445040 entries, 0 to 1445039
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1445040 non-null  int64
#  1   ActivityMinute  1445040 non-null  object
#  2   Steps           1445040 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 33.1+ MB
# None
# (2, 8)
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 2
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              2 non-null      int64
#  1   Date            2 non-null      object
#  2   WeightKg        2 non-null      float64
#  3   WeightPounds    2 non-null      float64
#  4   Fat             2 non-null      float64
#  5   BMI             2 non-null      float64
#  6   IsManualReport  2 non-null      bool
#  7   LogId           2 non-null      int64
# dtypes: bool(1), float64(4), int64(2), object(1)
# memory usage: 130.0+ bytes
# None

# %% [markdown]
# Saving cleaned datasets

# %%
heart_rate["Time"] = pd.to_datetime(heart_rate ["Time"], format='%m/%d/%Y %I:%M:%S %p')
hourly_calories["ActivityHour"] = pd.to_datetime(hourly_calories ["ActivityHour"], format='%m/%d/%Y %I:%M:%S %p')
hourly_intensities["ActivityHour"] = pd.to_datetime(hourly_intensities ["ActivityHour"], format='%m/%d/%Y %I:%M:%S %p')
hourly_steps["ActivityHour"] = pd.to_datetime(hourly_steps ["ActivityHour"], format='%m/%d/%Y %I:%M:%S %p')
minute_calories["ActivityMinute"] = pd.to_datetime(minute_calories ["ActivityMinute"], format='%m/%d/%Y %I:%M:%S %p')
minute_intensities["ActivityMinute"] = pd.to_datetime(minute_intensities ["ActivityMinute"], format='%m/%d/%Y %I:%M:%S %p')
minute_METs["ActivityMinute"] = pd.to_datetime(minute_METs ["ActivityMinute"], format='%m/%d/%Y %I:%M:%S %p')
minute_sleep["date"] = pd.to_datetime(minute_sleep ["date"], format='%m/%d/%Y %I:%M:%S %p')
minute_steps["ActivityMinute"] = pd.to_datetime(minute_steps ["ActivityMinute"], format='%m/%d/%Y %I:%M:%S %p')
weight["Date"] = pd.to_datetime(weight ["Date"], format='%m/%d/%Y %I:%M:%S %p')

# %%
for name, df in datasets:
  print(df.shape)
  print(df.info())
# Out:
# (457, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
#  13  SedentaryMinutes          457 non-null    int64
#  14  Calories                  457 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 53.7+ KB
# None
# (1154681, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1154681 entries, 0 to 1154680
# Data columns (total 3 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   Id      1154681 non-null  int64
#  1   Time    1154681 non-null  datetime64[ns]
#  2   Value   1154681 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 26.4 MB
# None
# (24084, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24084 entries, 0 to 24083
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            24084 non-null  int64
#  1   ActivityHour  24084 non-null  datetime64[ns]
#  2   Calories      24084 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 564.6 KB
# None
# (24084, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24084 entries, 0 to 24083
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                24084 non-null  int64
#  1   ActivityHour      24084 non-null  datetime64[ns]
#  2   TotalIntensity    24084 non-null  int64
#  3   AverageIntensity  24084 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 752.8 KB
# None
# (24084, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24084 entries, 0 to 24083
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            24084 non-null  int64
#  1   ActivityHour  24084 non-null  datetime64[ns]
#  2   StepTotal     24084 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 564.6 KB
# None
# (1445040, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445040 entries, 0 to 1445039
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1445040 non-null  int64
#  1   ActivityMinute  1445040 non-null  datetime64[ns]
#  2   Calories        1445040 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 33.1 MB
# None
# (1445040, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445040 entries, 0 to 1445039
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1445040 non-null  int64
#  1   ActivityMinute  1445040 non-null  datetime64[ns]
#  2   Intensity       1445040 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 33.1 MB
# None
# (1445040, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445040 entries, 0 to 1445039
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1445040 non-null  int64
#  1   ActivityMinute  1445040 non-null  datetime64[ns]
#  2   METs            1445040 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 33.1 MB
# None
# (198034, 4)
# <class 'pandas.core.frame.DataFrame'>
# Index: 198034 entries, 0 to 198558
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Id      198034 non-null  int64
#  1   date    198034 non-null  datetime64[ns]
#  2   value   198034 non-null  int64
#  3   logId   198034 non-null  int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 7.6 MB
# None
# (1445040, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445040 entries, 0 to 1445039
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1445040 non-null  int64
#  1   ActivityMinute  1445040 non-null  datetime64[ns]
#  2   Steps           1445040 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 33.1 MB
# None
# (2, 8)
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 2
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              2 non-null      int64
#  1   Date            2 non-null      datetime64[ns]
#  2   WeightKg        2 non-null      float64
#  3   WeightPounds    2 non-null      float64
#  4   Fat             2 non-null      float64
#  5   BMI             2 non-null      float64
#  6   IsManualReport  2 non-null      bool
#  7   LogId           2 non-null      int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(2)
# memory usage: 130.0 bytes
# None

# %%
for name, df in datasets:
  df.to_csv(f"{name}_cleaned.csv", index = False)
  print(f"Dataset {name} saved as {name}_cleaned.csv")
# Out:
# Dataset daily_activity saved as daily_activity_cleaned.csv
# Dataset heart_rate saved as heart_rate_cleaned.csv
# Dataset hourly_calories saved as hourly_calories_cleaned.csv
# Dataset hourly_intensities saved as hourly_intensities_cleaned.csv
# Dataset hourly_steps saved as hourly_steps_cleaned.csv
# Dataset minute_calories saved as minute_calories_cleaned.csv
# Dataset minute_intensities saved as minute_intensities_cleaned.csv
# Dataset minute_METs saved as minute_METs_cleaned.csv
# Dataset minute_sleep saved as minute_sleep_cleaned.csv
# Dataset minute_steps saved as minute_steps_cleaned.csv
# Dataset weight saved as weight_cleaned.csv

# %%
for name, df in datasets:
  print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-efb091312f5e> in <cell line: 1>()
# ----> 1 for name, df in datasets:
#       2   print(df.columns)
#
# NameError: name 'datasets' is not defined
